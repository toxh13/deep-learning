# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import layers, models
import tensorflow.keras as keras
from tensorflow.keras.utils import to_categorical
import pandas as pd

# %%
df=pd.read_csv('D:GC/DSA_features.csv')
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
# 피처와 레이블 분리
X = df.drop(['activity', 'people'], axis=1).values
y = df['activity'].values

# %%
# activity 레이블 인코딩
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# 레이블을 원-핫 인코딩
y_categorical = to_categorical(y_encoded)
n_classes = y_categorical.shape[1]

# %%
# 데이터 전처리: 트랜스포머 입력을 위해 reshape (batch_size, timesteps, features)
X_reshaped = np.expand_dims(X, axis=1)  # 시퀀스 차원이 없다고 가정하여 추가

# %%
# 데이터 분할: 훈련과 테스트 셋 분리
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_reshaped, y_encoded, test_size=0.2, random_state=42)

# %%
# 트랜스포머 인코더 정의
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
# 모델 생성 함수 정의
def build_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0, mlp_dropout=0):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)
    
    # 글로벌 평균 풀링
    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    
    # MLP 유닛 추가
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    
    # 최종 출력층
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    
    # 모델 컴파일
    return keras.Model(inputs, outputs)

# %%
# 모델 구성
input_shape = x_train.shape[1:]  # 시퀀스와 피처의 모양
model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,  # 트랜스포머 블록 수
    mlp_units=[128],           # MLP 유닛 크기
    dropout=0.25,
    mlp_dropout=0.4
)

# 모델 컴파일
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["sparse_categorical_accuracy"],
)

# 모델 요약 출력
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 1, 270)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 1, 270)            │       1,109,262 │ input_layer[0][0],         │
# │ (MultiHeadAttention)          │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_1 (Dropout)           │ (None, 1, 270)            │               0 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 1, 270)            │             540 │ dropout_1[0][0]            │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 1, 270)            │               0 │ layer_normalization[0][0], │
# │                               │                           │                 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d (Conv1D)               │ (None, 1, 4)              │           1,084 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 1, 4)              │               0 │ conv1d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_1 (Conv1D)             │ (None, 1, 270)            │           1,350 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_1         │ (None, 1, 270)            │             540 │ conv1d_1[0][0]             │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_1 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_1[0][… │
# │                               │                           │                 │ add[0][0]                  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_1        │ (None, 1, 270)            │       1,109,262 │ add_1[0][0], add_1[0][0]   │
# │ (MultiHeadAttention)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_4 (Dropout)           │ (None, 1, 270)            │               0 │ multi_head_attention_1[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_2         │ (None, 1, 270)            │             540 │ dropout_4[0][0]            │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_2 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_2[0][… │
# │                               │                           │                 │ add_1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 1, 4)              │           1,084 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_5 (Dropout)           │ (None, 1, 4)              │               0 │ conv1d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 1, 270)            │           1,350 │ dropout_5[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_3         │ (None, 1, 270)            │             540 │ conv1d_3[0][0]             │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_3 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_3[0][… │
# │                               │                           │                 │ add_2[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_2        │ (None, 1, 270)            │       1,109,262 │ add_3[0][0], add_3[0][0]   │
# │ (MultiHeadAttention)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_7 (Dropout)           │ (None, 1, 270)            │               0 │ multi_head_attention_2[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_4         │ (None, 1, 270)            │             540 │ dropout_7[0][0]            │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_4 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_4[0][… │
# │                               │                           │                 │ add_3[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 1, 4)              │           1,084 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_8 (Dropout)           │ (None, 1, 4)              │               0 │ conv1d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_5 (Conv1D)             │ (None, 1, 270)            │           1,350 │ dropout_8[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_5         │ (None, 1, 270)            │             540 │ conv1d_5[0][0]             │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_5 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_5[0][… │
# │                               │                           │                 │ add_4[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention_3        │ (None, 1, 270)            │       1,109,262 │ add_5[0][0], add_5[0][0]   │
# │ (MultiHeadAttention)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_10 (Dropout)          │ (None, 1, 270)            │               0 │ multi_head_attention_3[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_6         │ (None, 1, 270)            │             540 │ dropout_10[0][0]           │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_6 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_6[0][… │
# │                               │                           │                 │ add_5[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_6 (Conv1D)             │ (None, 1, 4)              │           1,084 │ add_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_11 (Dropout)          │ (None, 1, 4)              │               0 │ conv1d_6[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_7 (Conv1D)             │ (None, 1, 270)            │           1,350 │ dropout_11[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization_7         │ (None, 1, 270)            │             540 │ conv1d_7[0][0]             │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add_7 (Add)                   │ (None, 1, 270)            │               0 │ layer_normalization_7[0][… │
# │                               │                           │                 │ add_6[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling1d      │ (None, 270)               │               0 │ add_7[0][0]                │
# │ (GlobalAveragePooling1D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │          34,688 │ global_average_pooling1d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_12 (Dropout)          │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 19)                │           2,451 │ dropout_12[0][0]           │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 4,488,243 (17.12 MB)
#  Trainable params: 4,488,243 (17.12 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 콜백 설정 (조기 종료)
callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]

# 모델 학습
model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=callbacks,
)

# 모델 평가
model.evaluate(x_test, y_test, verbose=1)
# Out:
# Epoch 1/50
# C:\Users\toxh1\anaconda3\Lib\site-packages\keras\src\ops\nn.py:545: UserWarning: You are using a softmax over axis 3 of a tensor of shape (None, 4, 1, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 37s 168ms/step - loss: 7.8512 - sparse_categorical_accuracy: 0.2753 - val_loss: 0.9207 - val_sparse_categorical_accuracy: 0.7822
# Epoch 2/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 151ms/step - loss: 2.0865 - sparse_categorical_accuracy: 0.5784 - val_loss: 0.5912 - val_sparse_categorical_accuracy: 0.8760
# Epoch 3/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 157ms/step - loss: 1.2261 - sparse_categorical_accuracy: 0.6798 - val_loss: 0.4190 - val_sparse_categorical_accuracy: 0.8856
# Epoch 4/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.8888 - sparse_categorical_accuracy: 0.7573 - val_loss: 0.3064 - val_sparse_categorical_accuracy: 0.9062
# Epoch 5/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.8141 - sparse_categorical_accuracy: 0.7853 - val_loss: 0.2228 - val_sparse_categorical_accuracy: 0.9363
# Epoch 6/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 152ms/step - loss: 0.5786 - sparse_categorical_accuracy: 0.8356 - val_loss: 0.1526 - val_sparse_categorical_accuracy: 0.9521
# Epoch 7/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 151ms/step - loss: 0.4632 - sparse_categorical_accuracy: 0.8566 - val_loss: 0.1486 - val_sparse_categorical_accuracy: 0.9575
# Epoch 8/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 151ms/step - loss: 0.3769 - sparse_categorical_accuracy: 0.8821 - val_loss: 0.1187 - val_sparse_categorical_accuracy: 0.9712
# Epoch 9/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.3505 - sparse_categorical_accuracy: 0.8859 - val_loss: 0.0937 - val_sparse_categorical_accuracy: 0.9795
# Epoch 10/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s
50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0804 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0518 - val_sparse_categorical_accuracy: 0.9842
# Epoch 32/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 152ms/step - loss: 0.0841 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9822
# Epoch 33/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 154ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9745 - val_loss: 0.0540 - val_sparse_categorical_accuracy: 0.9863
# Epoch 34/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9870
# Epoch 35/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 152ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9829
# Epoch 36/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0778 - sparse_categorical_accuracy: 0.9709 - val_loss: 0.0752 - val_sparse_categorical_accuracy: 0.9795
# Epoch 37/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 157ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.0479 - val_sparse_categorical_accuracy: 0.9870
# Epoch 38/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 156ms/step - loss: 0.1312 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.0649 - val_sparse_categorical_accuracy: 0.9808
# Epoch 39/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.0902 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.0565 - val_sparse_categorical_accuracy: 0.9836
# Epoch 40/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 160ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.0491 - val_sparse_categorical_accuracy: 0.9884
# Epoch 41/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 157ms/step - loss: 0.0788 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.0554 - val_sparse_categorical_accuracy: 0.9870
# Epoch 42/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 162ms/step - loss: 0.0712 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.0456 - val_sparse_categorical_accuracy: 0.9849
# Epoch 43/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - loss: 0.0699 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9842
# Epoch 44/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - loss: 0.0715 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.0535 - val_sparse_categorical_accuracy: 0.9842
# Epoch 45/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 155ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0566 - val_sparse_categorical_accuracy: 0.9808
# Epoch 46/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - loss: 0.0639 - sparse_categorical_accuracy: 0.9765 - val_loss: 0.0493 - val_sparse_categorical_accuracy: 0.9856
# Epoch 47/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9729 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9890
# Epoch 48/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - loss: 0.0581 - sparse_categorical_accuracy: 0.9763 - val_loss: 0.0450 - val_sparse_categorical_accuracy: 0.9890
# Epoch 49/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 15s 159ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9870
# Epoch 50/50
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 14s 153ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9811 - val_loss: 0.0511 - val_sparse_categorical_accuracy: 0.9856
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9886
# [0.06413568556308746, 0.9890350699424744]
